# %%
# For LlamaIndex
# !pip install llama-parse llama-index llama-index-embeddings-openai nltk

# For LangChain
# !pip install langchain langchain-text-splitters langchain-community langchain-openai tiktoken
# !pip install pypdf pymupdf pdfplumber unstructured
# Out:
# Requirement already satisfied: llama-parse in /usr/local/lib/python3.12/dist-packages (0.6.88)
# Requirement already satisfied: llama-index in /usr/local/lib/python3.12/dist-packages (0.12.52)
# Requirement already satisfied: llama-index-embeddings-openai in /usr/local/lib/python3.12/dist-packages (0.3.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: llama-cloud-services>=0.6.88 in /usr/local/lib/python3.12/dist-packages (from llama-parse) (0.6.88)
# Requirement already satisfied: llama-index-agent-openai<0.5,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from llama-index) (0.4.12)
# Requirement already satisfied: llama-index-cli<0.5,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from llama-index) (0.4.4)
# Requirement already satisfied: llama-index-core<0.13,>=0.12.52.post1 in /usr/local/lib/python3.12/dist-packages (from llama-index) (0.12.52.post1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from llama-index) (0.6.11)
# Requirement already satisfied: llama-index-llms-openai<0.5,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from llama-index) (0.4.7)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.6,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index) (0.5.3)
# Requirement already satisfied: llama-index-program-openai<0.4,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from llama-index) (0.3.2)
# Requirement already satisfied: llama-index-question-gen-openai<0.4,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-readers-file<0.5,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from llama-index) (0.4.11)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from llama-index) (0.4.0)
# Requirement already satisfied: openai>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-embeddings-openai) (1.109.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: llama-cloud==0.1.45 in /usr/local/lib/python3.12/dist-packages (from llama-cloud-services>=0.6.88->llama-parse) (0.1.45)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.12/dist-packages (from llama-cloud-services>=0.6.88->llama-parse) (25.0)
# Requirement already satisfied: platformdirs<5,>=4.3.7 in /usr/local/lib/python3.12/dist-packages (from llama-cloud-services>=0.6.88->llama-parse) (4.5.1)
# Requirement already satisfied: pydantic!=2.10,>=2.8 in /usr/local/lib/python3.12/dist-packages (from llama-cloud-services>=0.6.88->llama-parse) (2.12.3)
# Requirement already satisfied: python-dotenv<2,>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from llama-cloud-services>=0.6.88->llama-parse) (1.2.1)
# Requirement already satisfied: tenacity<10.0,>=8.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-cloud-services>=0.6.88->llama-parse) (9.1.2)
# Requirement already satisfied: certifi>=2024.7.4 in /usr/local/lib/python3.12/dist-packages (from llama-cloud==0.1.45->llama-cloud-services>=0.6.88->llama-parse) (2025.11.12)
# Requirement already satisfied: httpx>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from llama-cloud==0.1.45->llama-cloud-services>=0.6.88->llama-parse) (0.28.1)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.13,>=0.12.52.post1->llama-index) (3.13.2)
# Requirement already satisfied: aiosqlite in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.13,>=0.12.52.post1->llama-index) (0.22.0)
# Requirement already satisfied: banks<3,>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.13,>=0.12.52.post1->llama-index) (2.2.0)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.13,>=0.12.52.post1->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.13,>=0.12.52.post1->llama-index) (1.3.1)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.13,>=0.12.52.post1->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.13,>=0.12.52.post1->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.13,>=0.12.52.post1->llama-index) (2025.3.0)
# Requirement already satisfied: llama-index-workflows<2,>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.13,>=0.12.52.post1->llama-index) (1.3.0)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.13,>=0.12.52.post1->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.13,>=0.12.52.post1->llama-index) (3.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.13,>=0.12.52.post1->llama-index) (2.0.2)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.13,>=0.12.52.post1->llama-index) (11.3.0)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.13,>=0.12.52.post1->llama-index) (6.0.3)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.13,>=0.12.52.post1->llama-index) (2.32.5)
# Requirement already satisfied: setuptools>=80.9.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.13,>=0.12.52.post1->llama-index) (80.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.52.post1->llama-index) (2.0.45)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.13,>=0.12.52.post1->llama-index) (0.12.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.13,>=0.12.52.post1->llama-index) (4.15.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.13,>=0.12.52.post1->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.13,>=0.12.52.post1->llama-index) (2.0.1)
# Requirement already satisfied: beautifulsoup4<5,>=4.12.3 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (4.13.5)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (0.7.1)
# Requirement already satisfied: pandas<2.3.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.2.2)
# Requirement already satisfied: pypdf<6,>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (5.9.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (0.0.26)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.1.0->llama-index-embeddings-openai) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.1.0->llama-index-embeddings-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.1.0->llama-index-embeddings-openai) (0.12.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.1.0->llama-index-embeddings-openai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.52.post1->llama-index) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.52.post1->llama-index) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.52.post1->llama-index) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.52.post1->llama-index) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.52.post1->llama-index) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.52.post1->llama-index) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.52.post1->llama-index) (1.22.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-embeddings-openai) (3.11)
# Requirement already satisfied: griffe in /usr/local/lib/python3.12/dist-packages (from banks<3,>=2.2.0->llama-index-core<0.13,>=0.12.52.post1->llama-index) (1.15.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from banks<3,>=2.2.0->llama-index-core<0.13,>=0.12.52.post1->llama-index) (3.1.6)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5,>=4.12.3->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.8)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.20.0->llama-cloud==0.1.45->llama-cloud-services>=0.6.88->llama-parse) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.20.0->llama-cloud==0.1.45->llama-cloud-services>=0.6.88->llama-parse) (0.16.0)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-workflows<2,>=1.0.1->llama-index-core<0.13,>=0.12.52.post1->llama-index) (0.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.10,>=2.8->llama-cloud-services>=0.6.88->llama-parse) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.10,>=2.8->llama-cloud-services>=0.6.88->llama-parse) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.10,>=2.8->llama-cloud-services>=0.6.88->llama-parse) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->llama-index-core<0.13,>=0.12.52.post1->llama-index) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->llama-index-core<0.13,>=0.12.52.post1->llama-index) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.52.post1->llama-index) (3.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.13,>=0.12.52.post1->llama-index) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json->llama-index-core<0.13,>=0.12.52.post1->llama-index) (3.26.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index) (1.17.0)
# Requirement already satisfied: colorama>=0.4 in /usr/local/lib/python3.12/dist-packages (from griffe->banks<3,>=2.2.0->llama-index-core<0.13,>=0.12.52.post1->llama-index) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->banks<3,>=2.2.0->llama-index-core<0.13,>=0.12.52.post1->llama-index) (3.0.3)
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: langchain-text-splitters in /usr/local/lib/python3.12/dist-packages (1.1.0)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.12/dist-packages (0.4.1)
# Requirement already satisfied: langchain-openai in /usr/local/lib/python3.12/dist-packages (1.1.6)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (0.12.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.2.6)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.0.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.12.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.45)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.59)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (1.109.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken) (2025.11.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.12.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.0)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2025.11.12)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: pypdf in /usr/local/lib/python3.12/dist-packages (5.9.0)
# Collecting pymupdf
#   Using cached pymupdf-1.26.7-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Collecting pdfplumber
#   Using cached pdfplumber-0.11.9-py3-none-any.whl.metadata (43 kB)
# Collecting unstructured
#   Using cached unstructured-0.18.26-py3-none-any.whl.metadata (25 kB)
# Collecting pdfminer.six==20251230 (from pdfplumber)
#   Using cached pdfminer_six-20251230-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.12/dist-packages (from pdfplumber) (11.3.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Using cached pypdfium2-5.3.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (67 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20251230->pdfplumber) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20251230->pdfplumber) (43.0.3)
# Requirement already satisfied: filetype in /usr/local/lib/python3.12/dist-packages (from unstructured) (1.2.0)
# Collecting python-magic (from unstructured)
#   Using cached python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from unstructured) (6.0.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from unstructured) (3.9.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from unstructured) (2.32.5)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from unstructured) (4.13.5)
# Collecting emoji (from unstructured)
#   Using cached emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.12/dist-packages (from unstructured) (0.6.7)
# Collecting python-iso639 (from unstructured)
#   Using cached python_iso639-2025.11.16-py3-none-any.whl.metadata (15 kB)
# Collecting langdetect (from unstructured)
#   Using cached langdetect-1.0.9.tar.gz (981 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from unstructured) (2.0.2)
# Collecting rapidfuzz (from unstructured)
#   Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Collecting backoff (from unstructured)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from unstructured) (4.15.0)
# Collecting unstructured-client (from unstructured)
#   Downloading unstructured_client-0.42.6-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from unstructured) (2.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from unstructured) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from unstructured) (5.9.5)
# Collecting python-oxmsg (from unstructured)
#   Downloading python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.12/dist-packages (from unstructured) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->unstructured) (2.8)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json->unstructured) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.12/dist-packages (from html5lib->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->unstructured) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->unstructured) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk->unstructured) (2025.11.3)
# Collecting olefile (from python-oxmsg->unstructured)
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->unstructured) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->unstructured) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->unstructured) (2025.11.12)
# Requirement already satisfied: aiofiles>=24.1.0 in /usr/local/lib/python3.12/dist-packages (from unstructured-client->unstructured) (24.1.0)
# Requirement already satisfied: httpcore>=1.0.9 in /usr/local/lib/python3.12/dist-packages (from unstructured-client->unstructured) (1.0.9)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.12/dist-packages (from unstructured-client->unstructured) (0.28.1)
# Requirement already satisfied: pydantic>=2.11.2 in /usr/local/lib/python3.12/dist-packages (from unstructured-client->unstructured) (2.12.3)
# Collecting pypdf
#   Downloading pypdf-6.5.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.0.0)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore>=1.0.9->unstructured-client->unstructured) (0.16.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.12.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.12/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.4.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.1.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.23)
# Downloading pymupdf-1.26.7-cp310-abi3-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 62.8 MB/s eta 0:00:00
# Downloading pdfplumber-0.11.9-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.9 MB/s eta 0:00:00
# Downloading pdfminer_six-20251230-py3-none-any.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 69.2 MB/s eta 0:00:00
# Downloading unstructured-0.18.26-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 60.8 MB/s eta 0:00:00
# Downloading pypdfium2-5.3.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 77.6 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 39.6 MB/s eta 0:00:00
# Downloading python_iso639-2025.11.16-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.8/167.8 kB 15.0 MB/s eta 0:00:00
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 77.4 MB/s eta 0:00:00
# Downloading unstructured_client-0.42.6-py3-none-any.whl (219 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.6/219.6 kB 17.3 MB/s eta 0:00:00
# Downloading pypdf-6.5.0-py3-none-any.whl (329 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.6/329.6 kB 24.2 MB/s eta 0:00:00
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 9.0 MB/s eta 0:00:00
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993332 sha256=a52882e05cf2e4c2e68a65e60461655efc1d7abe54587c45237dc7ed084636bc
#   Stored in directory: /root/.cache/pip/wheels/c1/67/88/e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# Installing collected packages: rapidfuzz, python-magic, python-iso639, pypdfium2, pypdf, pymupdf, olefile, langdetect, emoji, backoff, python-oxmsg, unstructured-client, pdfminer.six, unstructured, pdfplumber
#   Attempting uninstall: pypdf
#     Found existing installation: pypdf 5.9.0
#     Uninstalling pypdf-5.9.0:
#       Successfully uninstalled pypdf-5.9.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index-readers-file 0.4.11 requires pypdf<6,>=5.1.0, but you have pypdf 6.5.0 which is incompatible.
# Successfully installed backoff-2.2.1 emoji-2.15.0 langdetect-1.0.9 olefile-0.47 pdfminer.six-20251230 pdfplumber-0.11.9 pymupdf-1.26.7 pypdf-6.5.0 pypdfium2-5.3.0 python-iso639-2025.11.16 python-magic-0.4.27 python-oxmsg-0.0.2 rapidfuzz-3.14.3 unstructured-0.18.26 unstructured-client-0.42.6

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.2.1)

# %%
from pprint import pprint

# %%
from dotenv import load_dotenv
import os

load_dotenv()  # loads .env into environment variables

secret_key = os.getenv("LLAMA_CLOUD_API_KEY")

# %% [markdown]
# **PDF Document Parsing Using LLamaParse**

# %%
import os
from llama_parse import LlamaParse

# Initialize parser
parser = LlamaParse(
    result_type="markdown",  # or "text"
    verbose=True
)

# Parse PDF
documents = parser.load_data("/content/sample-local-pdf.pdf")
len(documents), type(documents), type(documents[0])
# Out:
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validate_default' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'validate_default' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# Started parsing the file under job_id b5d5d9c8-a3dd-487e-b0a5-3d14b9cf8c69
# (3, list, llama_index.core.schema.Document)

# %%
pprint(dict(documents[0]))
# Out:
# {'audio_resource': None,
#  'embedding': None,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '09942564-dfa8-42c8-bfcc-a49cc4983fdb',
#  'image_resource': None,
#  'metadata': {},
#  'metadata_separator': '\n',
#  'metadata_template': '{key}: {value}',
#  'relationships': {},
#  'text_resource': MediaResource(embeddings=None, data=None, text='Sample PDF\nCreated for testing PDFObject\n\nThis PDF is three pages long. Three long pages. Or three short pages if you’re optimistic. Is it the same as saying “three long minutes”, knowing that all minutes are the same duration, and one cannot possibly be longer than the other? If these pages are all the same size, can one possibly be longer than the other?\n\nI digress. Here’s some Latin. Lorem ipsum dolor sit amet, consectetur adipiscing elit. Integer nec odio. Praesent libero. Sed cursus ante dapibus diam. Sed nisi. Nulla quis sem at nibh elementum imperdiet. Duis sagittis ipsum. Praesent mauris. Fusce nec tellus sed augue semper porta. Mauris massa. Vestibulum lacinia arcu eget nulla. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Curabitur sodales ligula in libero.\n\nSed dignissim lacinia nunc. Curabitur tortor. Pellentesque nibh. Aenean quam. In scelerisque sem at dolor. Maecenas mattis. Sed convallis tristique sem. Proin ut ligula vel nunc egestas porttitor. Morbi lectus risus, iaculis vel, suscipit quis, luctus non, massa. Fusce ac turpis quis ligula lacinia aliquet. Mauris ipsum. Nulla metus metus, ullamcorper vel, tincidunt sed, euismod in, nibh.\n\nQuisque volutpat condimentum velit. Class aptent taciti sociosqu ad litora torquent per conubia nostra, per inceptos himenaeos. Nam nec ante. Sed lacinia, urna non tincidunt mattis, tortor neque adipiscing diam, a cursus ipsum ante quis turpis. Nulla facilisi. Ut fringilla. Suspendisse potenti. Nunc feugiat mi a tellus consequat imperdiet. Vestibulum sapien. Proin quam. Etiam ultrices.\n\nSuspendisse in justo eu magna luctus suscipit. Sed lectus. Integer euismod lacus luctus magna. Quisque cursus, metus vitae pharetra auctor, sem massa mattis sem, at interdum magna augue eget diam. Vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia Curae; Morbi lacinia molestie dui. Praesent blandit dolor. Sed non quam. In vel mi sit amet augue congue elementum. Morbi in ipsum sit amet pede facilisis laoreet. Donec lacus nunc, viverra nec, blandit vel, egestas et, augue. Vestibulum tincidunt malesuada tellus. Ut ultrices ultrices enim. Curabitur sit amet mauris.\n\nMorbi in dui quis est pulvinar ullamcorper. Nulla facilisi. Integer lacinia sollicitudin massa. Cras metus. Sed aliquet risus a tortor. Integer id quam. Morbi mi. Quisque nisl felis, venenatis tristique, dignissim in, ultrices sit amet, augue. Proin sodales libero eget ante. Nulla quam. Aenean laoreet. Vestibulum nisi lectus, commodo ac, facilisis ac, ultricies eu, pede. Ut orci risus, accumsan porttitor, cursus quis, aliquet eget, justo. Sed pretium blandit orci.\n\nUt eu diam at pede suscipit sodales. Aenean lectus elit, fermentum non, convallis id, sagittis at, neque. Nullam mauris orci, aliquet et, iaculis et, viverra vitae, ligula. Nulla ut felis in purus aliquam imperdiet. Maecenas aliquet mollis lectus. Vivamus consectetuer risus et tortor. Lorem\n\n1\n', path=None, url=None, mimetype=None),
#  'text_template': '{metadata_str}\n\n{content}',
#  'video_resource': None}

# %% [markdown]
# **LlamaIndex Chunking Techniques**
#
# LlamaIndex uses Node Parsers that convert Documents into Node objects, where each node is a chunk inheriting metadata from the parent document.

# %% [markdown]
# 1. **SentenceSplitter (Basic & Recommended)**

# %%
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core import Document

splitter1 = SentenceSplitter(
    chunk_size=1024,        # Target tokens per chunk
    chunk_overlap=20,       # Overlap between chunks
    paragraph_separator="\n\n\n",
    secondary_chunking_regex="[^,.;。]+[,.;。]?"
)
splitter2 = SentenceSplitter(
    chunk_size=256,        # Target tokens per chunk
    chunk_overlap=20,       # Overlap between chunks
    paragraph_separator="\n\n\n",
    secondary_chunking_regex="[^,.;。]+[,.;。]?"
)

# %%
splitter1
# Out:
# SentenceSplitter(include_metadata=True, include_prev_next_rel=True, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x7a3971caea20>, id_func=<function default_id_func at 0x7a397c980fe0>, chunk_size=1024, chunk_overlap=20, separator=' ', paragraph_separator='\n\n\n', secondary_chunking_regex='[^,.;。]+[,.;。]?')

# %%
nodes_with_splitter1 = splitter1.get_nodes_from_documents(documents)
nodes_with_splitter2 = splitter2.get_nodes_from_documents(documents)

print(f"Nodes with Splitter 1: \nType: {type(nodes_with_splitter1)}, \nNum_of_nodes: {len(nodes_with_splitter1)}", end="\n\n")
print(f"Nodes with Splitter 2: \nType: {type(nodes_with_splitter2)}, \nNum_of_nodes: {len(nodes_with_splitter2)}")
# Out:
# Nodes with Splitter 1:
# Type: <class 'list'>,
# Num_of_nodes: 4
#
# Nodes with Splitter 2:
# Type: <class 'list'>,
# Num_of_nodes: 15

# %%
pprint(dict(nodes_with_splitter1[0]))
# Out:
# {'embedding': None,
#  'end_char_idx': 2970,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '36900db6-1d83-4ed6-b871-6b6870b270c5',
#  'metadata': {},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='09942564-dfa8-42c8-bfcc-a49cc4983fdb', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='92477fef8bfaa85668c659571b7bd25684c419d76f41bcbb48bb49adecc8082c')},
#  'start_char_idx': 0,
#  'text': 'Sample PDF\n'
#          'Created for testing PDFObject\n'
#          '\n'
#          'This PDF is three pages long. Three long pages. Or three short pages '
#          'if you’re optimistic. Is it the same as saying “three long minutes”, '
#          'knowing that all minutes are the same duration, and one cannot '
#          'possibly be longer than the other? If these pages are all the same '
#          'size, can one possibly be longer than the other?\n'
#          '\n'
#          'I digress. Here’s some Latin. Lorem ipsum dolor sit amet, '
#          'consectetur adipiscing elit. Integer nec odio. Praesent libero. Sed '
#          'cursus ante dapibus diam. Sed nisi. Nulla quis sem at nibh elementum '
#          'imperdiet. Duis sagittis ipsum. Praesent mauris. Fusce nec tellus '
#          'sed augue semper porta. Mauris massa. Vestibulum lacinia arcu eget '
#          'nulla. Class aptent taciti sociosqu ad litora torquent per conubia '
#          'nostra, per inceptos himenaeos. Curabitur sodales ligula in libero.\n'
#          '\n'
#          'Sed dignissim lacinia nunc. Curabitur tortor. Pellentesque nibh. '
#          'Aenean quam. In scelerisque sem at dolor. Maecenas mattis. Sed '
#          'convallis tristique sem. Proin ut ligula vel nunc egestas porttitor. '
#          'Morbi lectus risus, iaculis vel, suscipit quis, luctus non, massa. '
#          'Fusce ac turpis quis ligula lacinia aliquet. Mauris ipsum. Nulla '
#          'metus metus, ullamcorper vel, tincidunt sed, euismod in, nibh.\n'
#          '\n'
#          'Quisque volutpat condimentum velit. Class aptent taciti sociosqu ad '
#          'litora torquent per conubia nostra, per inceptos himenaeos. Nam nec '
#          'ante. Sed lacinia, urna non tincidunt mattis, tortor neque '
#          'adipiscing diam, a cursus ipsum ante quis turpis. Nulla facilisi. Ut '
#          'fringilla. Suspendisse potenti. Nunc feugiat mi a tellus consequat '
#          'imperdiet. Vestibulum sapien. Proin quam. Etiam ultrices.\n'
#          '\n'
#          'Suspendisse in justo eu magna luctus suscipit. Sed lectus. Integer '
#          'euismod lacus luctus magna. Quisque cursus, metus vitae pharetra '
#          'auctor, sem massa mattis sem, at interdum magna augue eget diam. '
#          'Vestibulum ante ipsum primis in faucibus orci luctus et ultrices '
#          'posuere cubilia Curae; Morbi lacinia molestie dui. Praesent blandit '
#          'dolor. Sed non quam. In vel mi sit amet augue congue elementum. '
#          'Morbi in ipsum sit amet pede facilisis laoreet. Donec lacus nunc, '
#          'viverra nec, blandit vel, egestas et, augue. Vestibulum tincidunt '
#          'malesuada tellus. Ut ultrices ultrices enim. Curabitur sit amet '
#          'mauris.\n'
#          '\n'
#          'Morbi in dui quis est pulvinar ullamcorper. Nulla facilisi. Integer '
#          'lacinia sollicitudin massa. Cras metus. Sed aliquet risus a tortor. '
#          'Integer id quam. Morbi mi. Quisque nisl felis, venenatis tristique, '
#          'dignissim in, ultrices sit amet, augue. Proin sodales libero eget '
#          'ante. Nulla quam. Aenean laoreet. Vestibulum nisi lectus, commodo '
#          'ac, facilisis ac, ultricies eu, pede. Ut orci risus, accumsan '
#          'porttitor, cursus quis, aliquet eget, justo. Sed pretium blandit '
#          'orci.\n'
#          '\n'
#          'Ut eu diam at pede suscipit sodales. Aenean lectus elit, fermentum '
#          'non, convallis id, sagittis at, neque. Nullam mauris orci, aliquet '
#          'et, iaculis et, viverra vitae, ligula. Nulla ut felis in purus '
#          'aliquam imperdiet. Maecenas aliquet mollis lectus. Vivamus '
#          'consectetuer risus et tortor. Lorem\n'
#          '\n'
#          '1',
#  'text_template': '{metadata_str}\n\n{content}'}

# %%
pprint(dict(nodes_with_splitter2[0]))
# Out:
# {'embedding': None,
#  'end_char_idx': 869,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '87c12de1-381a-4c0c-baf2-d2b635660a07',
#  'metadata': {},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='09942564-dfa8-42c8-bfcc-a49cc4983fdb', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='92477fef8bfaa85668c659571b7bd25684c419d76f41bcbb48bb49adecc8082c'),
#                    <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='94893b92-e9f1-4058-ad76-8c803c7b63d9', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='f9030d151e905b83458cb3ceab0b58d6aa9a6abe2e261037f8a3ee32a9ef378a')},
#  'start_char_idx': 0,
#  'text': 'Sample PDF\n'
#          'Created for testing PDFObject\n'
#          '\n'
#          'This PDF is three pages long. Three long pages. Or three short pages '
#          'if you’re optimistic. Is it the same as saying “three long minutes”, '
#          'knowing that all minutes are the same duration, and one cannot '
#          'possibly be longer than the other? If these pages are all the same '
#          'size, can one possibly be longer than the other?\n'
#          '\n'
#          'I digress. Here’s some Latin. Lorem ipsum dolor sit amet, '
#          'consectetur adipiscing elit. Integer nec odio. Praesent libero. Sed '
#          'cursus ante dapibus diam. Sed nisi. Nulla quis sem at nibh elementum '
#          'imperdiet. Duis sagittis ipsum. Praesent mauris. Fusce nec tellus '
#          'sed augue semper porta. Mauris massa. Vestibulum lacinia arcu eget '
#          'nulla. Class aptent taciti sociosqu ad litora torquent per conubia '
#          'nostra, per inceptos himenaeos. Curabitur sodales ligula in libero.\n'
#          '\n'
#          'Sed dignissim lacinia nunc. Curabitur tortor.',
#  'text_template': '{metadata_str}\n\n{content}'}

# %%
pprint(dict(nodes_with_splitter2[1]))
# Out:
# {'embedding': None,
#  'end_char_idx': 1512,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '94893b92-e9f1-4058-ad76-8c803c7b63d9',
#  'metadata': {},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='09942564-dfa8-42c8-bfcc-a49cc4983fdb', node_type=<ObjectType.DOCUMENT: '4'>, metadata={}, hash='92477fef8bfaa85668c659571b7bd25684c419d76f41bcbb48bb49adecc8082c'),
#                    <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='87c12de1-381a-4c0c-baf2-d2b635660a07', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='c7e0d9657a10dc7ff95928b556c33f5939e31edcacde7c7b26acee50e3359fab'),
#                    <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='9531154a-162a-4776-8bf1-491d37954bb4', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='03e1cf68d62801060897ccaf9b7246811bef3776dfca4c65d006389ea1661a8f')},
#  'start_char_idx': 824,
#  'text': 'Sed dignissim lacinia nunc. Curabitur tortor. Pellentesque nibh. '
#          'Aenean quam. In scelerisque sem at dolor. Maecenas mattis. Sed '
#          'convallis tristique sem. Proin ut ligula vel nunc egestas porttitor. '
#          'Morbi lectus risus, iaculis vel, suscipit quis, luctus non, massa. '
#          'Fusce ac turpis quis ligula lacinia aliquet. Mauris ipsum. Nulla '
#          'metus metus, ullamcorper vel, tincidunt sed, euismod in, nibh.\n'
#          '\n'
#          'Quisque volutpat condimentum velit. Class aptent taciti sociosqu ad '
#          'litora torquent per conubia nostra, per inceptos himenaeos. Nam nec '
#          'ante. Sed lacinia, urna non tincidunt mattis, tortor neque '
#          'adipiscing diam, a cursus ipsum ante quis turpis. Nulla facilisi. Ut '
#          'fringilla. Suspendisse potenti.',
#  'text_template': '{metadata_str}\n\n{content}'}

# %%
# Inspect nodes : nodes_with_splitter1
print(f"Total nodes created: {len(nodes_with_splitter1)}")
print("\n=== First Node ===")
print(f"Node ID: {nodes_with_splitter1[0].node_id}")
print(f"Text length: {len(nodes_with_splitter1[0].text)} chars")
print(f"Metadata: {nodes_with_splitter1[0].metadata}")
print(f"\nContent preview:\n{nodes_with_splitter1[0].text[:300]}")

# Analyze relationships
print(f"\n=== Node Relationships ===")
print(f"Source doc: {nodes_with_splitter1[0].source_node}")
if len(nodes_with_splitter1) > 1:
    print(f"Next node: {nodes_with_splitter1[0].relationships.get('next')}")
# Out:
# Total nodes created: 4
#
# === First Node ===
# Node ID: 815cc067-83df-4a99-9de2-c8a3b1679844
# Text length: 2970 chars
# Metadata: {}
#
# Content preview:
# Sample PDF
# Created for testing PDFObject
#
# This PDF is three pages long. Three long pages. Or three short pages if you’re optimistic. Is it the same as saying “three long minutes”, knowing that all minutes are the same duration, and one cannot possibly be longer than the other? If these pages are all
#
# === Node Relationships ===
# Source doc: node_id='a138ae6d-a5a8-4b52-9e9d-4d3e68f58f92' node_type=<ObjectType.DOCUMENT: '4'> metadata={} hash='92477fef8bfaa85668c659571b7bd25684c419d76f41bcbb48bb49adecc8082c'
# Next node: None

# %%
# Inspect nodes : nodes_with_splitter2
print(f"Total nodes created: {len(nodes_with_splitter2)}")
print("\n=== First Node ===")
print(f"Node ID: {nodes_with_splitter2[0].node_id}")
print(f"Text length: {len(nodes_with_splitter2[0].text)} chars")
print(f"Metadata: {nodes_with_splitter2[0].metadata}")
print(f"\nContent preview:\n{nodes_with_splitter2[0].text[:300]}")

# Analyze relationships
print(f"\n=== Node Relationships ===")
print(f"Source doc: {nodes_with_splitter2[0].source_node}")
if len(nodes_with_splitter2) > 1:
    print(f"Next node: {nodes_with_splitter2[0].relationships.get('next')}")
# Out:
# Total nodes created: 15
#
# === First Node ===
# Node ID: 5833dd49-f87d-429f-866b-1e81975d89c4
# Text length: 869 chars
# Metadata: {}
#
# Content preview:
# Sample PDF
# Created for testing PDFObject
#
# This PDF is three pages long. Three long pages. Or three short pages if you’re optimistic. Is it the same as saying “three long minutes”, knowing that all minutes are the same duration, and one cannot possibly be longer than the other? If these pages are all
#
# === Node Relationships ===
# Source doc: node_id='a138ae6d-a5a8-4b52-9e9d-4d3e68f58f92' node_type=<ObjectType.DOCUMENT: '4'> metadata={} hash='92477fef8bfaa85668c659571b7bd25684c419d76f41bcbb48bb49adecc8082c'
# Next node: None

# %% [markdown]
# **Mixed Content PDF Hybrid Splitter**

# %%
import os
from llama_parse import LlamaParse

# Initialize parser
parser = LlamaParse(
    result_type="markdown",  # or "text"
    verbose=True
)

# Parse PDF
documents = parser.load_data("/content/mixed_document_10_page.pdf")
len(documents), type(documents), type(documents[0])
# Out:
# Started parsing the file under job_id 69c52dc2-7f9d-4f13-9a24-591822b8dff8
# (10, list, llama_index.core.schema.Document)

# %%
import re
from typing import List
from collections import Counter
from llama_index.core import Document
from llama_index.core.node_parser import SimpleNodeParser
from llama_index.core.text_splitter import TokenTextSplitter, SentenceSplitter

# ---------- Try to import CodeSplitter from the core path you mentioned ----------
try:
    from llama_index.core.node_parser import CodeSplitter
    HAS_CODE_SPLITTER = True
except Exception:
    HAS_CODE_SPLITTER = False

# ---------- TableTextSplitter (same as before; safe fallback) ----------
class TableTextSplitter:
    def __init__(self, rows_per_chunk: int = 20, row_overlap: int = 0):
        self.rows_per_chunk = max(1, int(rows_per_chunk))
        self.row_overlap = max(0, int(row_overlap))

    def _parse_table_lines(self, lines):
        # pipe-delimited first
        if any("|" in ln for ln in lines):
            def split_pipe(ln):
                s = ln.strip()
                if s.startswith("|"): s = s[1:]
                if s.endswith("|"): s = s[:-1]
                return [c.strip() for c in re.split(r"\|", s)]
            parsed = [split_pipe(ln) for ln in lines if ln.strip() != ""]
            header = parsed[0] if parsed else []
            rows = parsed[1:] if len(parsed) > 1 else []
            return {"header": header, "rows": rows}
        else:
            def split_ws(ln):
                parts = [p.strip() for p in re.split(r"\s{2,}", ln) if p.strip() != ""]
                return parts
            parsed = [split_ws(ln) for ln in lines if ln.strip() != ""]
            counts = [len(p) for p in parsed]
            if not counts:
                return None
            mode_count = Counter(counts).most_common(1)[0][0]
            filtered = [p for p in parsed if len(p) == mode_count]
            if not filtered:
                return None
            header = filtered[0]
            rows = filtered[1:] if len(filtered) > 1 else []
            return {"header": header, "rows": rows}

    def _rows_to_markdown(self, header, rows):
        def sanitize(cell):
            return str(cell).replace("\n", " ").strip()
        hdr = "| " + " | ".join(sanitize(h) for h in header) + " |"
        sep = "| " + " | ".join(["---"] * len(header)) + " |"
        r_strs = []
        for r in rows:
            cells = [sanitize(c) for c in r]
            if len(cells) < len(header):
                cells += [""] * (len(header) - len(cells))
            elif len(cells) > len(header):
                cells = cells[:len(header)]
            r_strs.append("| " + " | ".join(cells) + " |")
        return "\n".join([hdr, sep] + r_strs)

    def split_text(self, text: str):
        lines = [ln.rstrip() for ln in text.splitlines() if ln.strip() != ""]
        parsed = self._parse_table_lines(lines)
        if parsed is None:
            return [text.strip()]
        header = parsed["header"]
        rows = parsed["rows"]
        if not rows:
            return [self._rows_to_markdown(header, [])]
        chunks = []
        total_rows = len(rows)
        step = max(1, self.rows_per_chunk - self.row_overlap)
        for start in range(0, total_rows, step):
            end = min(start + self.rows_per_chunk, total_rows)
            chunk_rows = rows[start:end]
            chunks.append(self._rows_to_markdown(header, chunk_rows))
            if end == total_rows:
                break
        return chunks

# ---------- Heuristics for detection ----------
CODE_KEYWORDS = ["def ", "class ", "import ", "from ", "#include", "console.log", "printf(", "println(", "System.out."]
CODE_SYMBOLS_RE = r"[{};=><>#\(\)\[\]]"

def is_code_block(text: str, min_lines_for_code=2, symbol_ratio_threshold=0.03) -> bool:
    if not text or not text.strip():
        return False
    if "```" in text:
        return True
    lines = [ln for ln in text.splitlines() if ln.strip() != ""]
    if len(lines) >= min_lines_for_code:
        indented = sum(1 for ln in lines if ln.startswith("    ") or ln.startswith("\t"))
        if indented >= max(1, len(lines)//3):
            return True
    lower = text.lower()
    for kw in CODE_KEYWORDS:
        if kw in lower:
            return True
    symbols = len(re.findall(CODE_SYMBOLS_RE, text))
    if len(text) > 0 and (symbols / len(text) > symbol_ratio_threshold):
        return True
    ends_semi = sum(1 for ln in lines if ln.strip().endswith(";"))
    if ends_semi >= max(1, len(lines)//4):
        return True
    return False

def is_table_block(text: str, min_rows=2, min_cols=2, consistency_threshold=0.6) -> bool:
    if not text or not text.strip():
        return False
    lines = [ln.rstrip() for ln in text.splitlines() if ln.strip() != ""]
    if len(lines) < min_rows:
        return False
    if any("|" in ln for ln in lines):
        col_counts = [len([c for c in re.split(r"\|", ln) if c.strip() != ""]) for ln in lines]
    else:
        def split_cols(ln): return [p for p in re.split(r"\s{2,}", ln) if p.strip() != ""]
        col_counts = [len(split_cols(ln)) for ln in lines]
    valid = [c for c in col_counts if c >= min_cols]
    if not valid:
        return False
    cnt = Counter(col_counts)
    mode_count = cnt.most_common(1)[0][1]
    ratio = mode_count / len(lines)
    return ratio >= consistency_threshold and cnt.most_common(1)[0][0] >= min_cols

# ---------- Main dispatcher: uses CodeSplitter when available ----------
def hybrid_chunk_documents_with_codesplitter(
        documents: List[Document],
        paragraph_regex: str = r"\n{2,}",
        text_chunk_size: int = 128,
        text_overlap: int = 16,
        code_chunk_lines: int = 30,
        code_overlap_lines: int = 10,
        code_max_chars: int = 1500,
        table_rows_per_chunk: int = 20,
        table_row_overlap: int = 0,
):
    all_nodes = []

    # instantiate splitters (reuse)
    text_splitter = None
    try:
        text_splitter = SentenceSplitter(chunk_size=text_chunk_size, chunk_overlap=text_overlap)
    except Exception:
        text_splitter = TokenTextSplitter(chunk_size=text_chunk_size, chunk_overlap=text_overlap)

    table_splitter = TableTextSplitter(rows_per_chunk=table_rows_per_chunk, row_overlap=table_row_overlap)

    # prepare CodeSplitter if available
    code_splitter = None
    if HAS_CODE_SPLITTER:
        try:
            code_splitter = CodeSplitter(language="python",
                                         chunk_lines=code_chunk_lines,
                                         chunk_lines_overlap=code_overlap_lines,
                                         max_chars=code_max_chars)
        except Exception:
            code_splitter = None

    for doc in documents:
        # robustly extract text
        if hasattr(doc, "get_text"):
            text = doc.get_text()
        elif hasattr(doc, "text"):
            text = doc.text
        else:
            text = str(doc)

        # coarse break into blocks (paragraphs / blank lines)
        blocks = re.split(paragraph_regex, text)
        for b_idx, block in enumerate(blocks):
            block = block.strip()
            if not block:
                continue

            detected_table = is_table_block(block)
            detected_code = False if detected_table else is_code_block(block)

            # CASE 1: Table
            if detected_table:
                splitter_name = "table"
                # TableTextSplitter returns chunk strings; convert to Documents
                chunk_texts = table_splitter.split_text(block)
                for ci, ct in enumerate(chunk_texts):
                    tmp_doc = Document(text=ct, metadata={
                        "orig_doc_id": getattr(doc, "id_", None) or getattr(doc, "doc_id", None),
                        "page": getattr(doc, "metadata", {}).get("page") if getattr(doc, "metadata", None) else None,
                        "block_index": b_idx,
                        "detected_table": True,
                        "splitter": splitter_name,
                        "chunk_index": ci,
                    })
                    # use SimpleNodeParser to produce nodes from that small doc (keeps interface consistent)
                    # node_parser = SimpleNodeParser(text_splitter=TokenTextSplitter(chunk_size=10000, chunk_overlap=0))
                    # nodes = node_parser.get_nodes_from_documents([tmp_doc])
                    nodes = TokenTextSplitter(
                        chunk_size=10000,
                        chunk_overlap=0
                    ).get_nodes_from_documents([tmp_doc])

                    for n in nodes:
                        # n.node_info = {**(getattr(n, "node_info", {}) or {}), "splitter_used": splitter_name}
                        n.metadata = n.metadata or {}
                        n.metadata["splitter_used"] = splitter_name
                    all_nodes.extend(nodes)
                continue

            # CASE 2: Code
            if detected_code and code_splitter is not None:
                splitter_name = "code"
                # wrap block into a Document and call CodeSplitter.get_nodes_from_documents
                tmp_doc = Document(text=block, metadata={
                    "orig_doc_id": getattr(doc, "id_", None) or getattr(doc, "doc_id", None),
                    "page": getattr(doc, "metadata", {}).get("page") if getattr(doc, "metadata", None) else None,
                    "block_index": b_idx,
                    "detected_code": True,
                    "splitter": splitter_name,
                })
                try:
                    code_nodes = code_splitter.get_nodes_from_documents([tmp_doc])
                    for n in code_nodes:
                        # n.node_info = {**(getattr(n, "node_info", {}) or {}), "splitter_used": splitter_name}
                        n.metadata = n.metadata or {}
                        n.metadata["splitter_used"] = splitter_name
                    all_nodes.extend(code_nodes)
                    continue
                except Exception:
                    # fallback to TokenTextSplitter preserving newlines
                    pass

            # CASE 3: Text (or code fallback)
            if detected_code and code_splitter is None:
                splitter_name = "code_fallback"
                splitter_for_node = TokenTextSplitter(chunk_size=400, chunk_overlap=20)
            else:
                splitter_name = "sentence" if isinstance(text_splitter, SentenceSplitter) else "token"
                splitter_for_node = text_splitter

            # Use SimpleNodeParser to turn small block into nodes
            tmp_doc = Document(text=block, metadata={
                "orig_doc_id": getattr(doc, "id_", None) or getattr(doc, "doc_id", None),
                "page": getattr(doc, "metadata", {}).get("page") if getattr(doc, "metadata", None) else None,
                "block_index": b_idx,
                "detected_code": bool(detected_code),
                "detected_table": bool(detected_table),
                "splitter": splitter_name,
            })
            # node_parser = SimpleNodeParser(text_splitter=splitter_for_node)
            # nodes = node_parser.get_nodes_from_documents([tmp_doc])
            nodes = splitter_for_node.get_nodes_from_documents([tmp_doc])

            for n in nodes:
                # n.node_info = {**(getattr(n, "node_info", {}) or {}), "splitter_used": splitter_name}
                n.metadata = n.metadata or {}
                n.metadata["splitter_used"] = splitter_name
            all_nodes.extend(nodes)

    return all_nodes

# ----------------- Example usage -----------------
# nodes = hybrid_chunk_documents_with_codesplitter(documents)
# print("nodes:", len(nodes))
# print("sample node metadata:", nodes[0].node_info)

# %%
nodes = hybrid_chunk_documents_with_codesplitter(documents)

# %%
len(nodes)
# Out:
# 46

# %%
# pprint(nodes)
for nodeob in nodes:
    pprint(dict(nodeob))
    print("\n=====================================================\n")
# Out:
# {'embedding': None,
#  'end_char_idx': 29,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': 'e3cc8ec4-fcfe-49a2-a529-0b09b555b81f',
#  'metadata': {'block_index': 0,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': '07d3ec08-b4c7-48d7-8dcc-3b3c58f0d4fe',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='5f650162-9e05-401e-bec9-791cf3225ce6', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '07d3ec08-b4c7-48d7-8dcc-3b3c58f0d4fe', 'page': None, 'block_index': 0, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='57c3699890d31d53be16654720ecd67e94157d82b387bf4cc13d11056a478615')},
#  'start_char_idx': 0,
#  'text': 'Mixed Content Sample Document',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 11,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '538c553d-c8f5-4d77-b1b6-7ae648acbaf4',
#  'metadata': {'block_index': 1,
#               'detected_code': True,
#               'detected_table': False,
#               'orig_doc_id': '07d3ec08-b4c7-48d7-8dcc-3b3c58f0d4fe',
#               'page': None,
#               'splitter': 'code_fallback',
#               'splitter_used': 'code_fallback'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='eb7d67f6-c12e-4c7c-ba95-862a0325a7d4', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '07d3ec08-b4c7-48d7-8dcc-3b3c58f0d4fe', 'page': None, 'block_index': 1, 'detected_code': True, 'detected_table': False, 'splitter': 'code_fallback'}, hash='6eab2beaa987182fb31e3e5f9b0ffea90b1fcd5f03b75caeb0f5496f4ee54649')},
#  'start_char_idx': 0,
#  'text': '# Contents:',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 214,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '9cfd41ef-7ecb-4fd6-825a-b0225178a757',
#  'metadata': {'block_index': 2,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': '07d3ec08-b4c7-48d7-8dcc-3b3c58f0d4fe',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='00d6c820-ecd6-401a-a37a-d4f92e2d76f9', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '07d3ec08-b4c7-48d7-8dcc-3b3c58f0d4fe', 'page': None, 'block_index': 2, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='92ed353013f16f5fe5786c8f37a8e54563e6c8f62d851f369ca6ef368bf0c607'),
#                    <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='6d01d21e-7624-42d8-8d2a-2642d19fcf09', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='01eca463fa53a3a725516142f2d5ff5d3adfc55e35c19cf99e4c81175822da37')},
#  'start_char_idx': 0,
#  'text': '- 1. Introduction and overview (this page).\n'
#          '- 2-3. Normal prose / paragraphs.\n'
#          '- 4-5. Python code examples (functions, classes).\n'
#          '- 6-7. Tables and structured data.\n'
#          '- 8. Mixed: theory + code + table on the same page.',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 296,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '6d01d21e-7624-42d8-8d2a-2642d19fcf09',
#  'metadata': {'block_index': 2,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': '07d3ec08-b4c7-48d7-8dcc-3b3c58f0d4fe',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='00d6c820-ecd6-401a-a37a-d4f92e2d76f9', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '07d3ec08-b4c7-48d7-8dcc-3b3c58f0d4fe', 'page': None, 'block_index': 2, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='92ed353013f16f5fe5786c8f37a8e54563e6c8f62d851f369ca6ef368bf0c607'),
#                    <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='9cfd41ef-7ecb-4fd6-825a-b0225178a757', node_type=<ObjectType.TEXT: '1'>, metadata={'orig_doc_id': '07d3ec08-b4c7-48d7-8dcc-3b3c58f0d4fe', 'page': None, 'block_index': 2, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='d3e55ee3a07d377997f9b0e7067912eddb920e948e5231b5f1f15122483e10c1')},
#  'start_char_idx': 168,
#  'text': 'Mixed: theory + code + table on the same page.\n'
#          '- 9. Longer code listing (multi-line).\n'
#          '- 10. Conclusion &#x26; index of examples.',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 213,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': 'd79402d3-40e5-4b08-a4c1-ca17be5a1bcb',
#  'metadata': {'block_index': 1,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': '116723b0-71ed-4e3f-aaea-6a78f653c053',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='162e77fd-c1da-4481-b362-16817905eb4a', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '116723b0-71ed-4e3f-aaea-6a78f653c053', 'page': None, 'block_index': 1, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='13e34591de9a2417a05c37b4ae3a9409b9909ee53d15eadcc11789f217d02f31'),
#                    <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='cb99c99a-c8cd-4c13-8c6e-fc2611621f6c', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='af0b22d8a6bdb895910a168632082e2a30014284b41c5110d2ccd4275da875fe')},
#  'start_char_idx': 0,
#  'text': 'Lorem ipsum dolor sit amet, consectetur adipiscing elit. Integer nec '
#          'odio. Praesent libero. Sed cursus ante dapibus diam. Sed nisi. Nulla '
#          'quis sem at nibh elementum imperdiet. Duis sagittis ipsum. Praesent '
#          'mauris.',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 304,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': 'cb99c99a-c8cd-4c13-8c6e-fc2611621f6c',
#  'metadata': {'block_index': 1,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': '116723b0-71ed-4e3f-aaea-6a78f653c053',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='162e77fd-c1da-4481-b362-16817905eb4a', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '116723b0-71ed-4e3f-aaea-6a78f653c053', 'page': None, 'block_index': 1, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='13e34591de9a2417a05c37b4ae3a9409b9909ee53d15eadcc11789f217d02f31'),
#                    <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='d79402d3-40e5-4b08-a4c1-ca17be5a1bcb', node_type=<ObjectType.TEXT: '1'>, metadata={'orig_doc_id': '116723b0-71ed-4e3f-aaea-6a78f653c053', 'page': None, 'block_index': 1, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='e0eb3891c2e70f124639dcbfca459079343359940367a843f20ace43ea0580f9')},
#  'start_char_idx': 176,
#  'text': 'Duis sagittis ipsum. Praesent mauris. Fusce nec tellus sed augue '
#          'semper porta. Mauris massa. Vestibulum lacinia arcu eget nulla.',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 213,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': 'c21786e8-5384-40be-bd49-a80e2728a463',
#  'metadata': {'block_index': 2,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': '116723b0-71ed-4e3f-aaea-6a78f653c053',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='f49aea42-6215-4727-b373-7cee31698a8c', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '116723b0-71ed-4e3f-aaea-6a78f653c053', 'page': None, 'block_index': 2, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='42832909301d3656a4c27177d3610e4778b653f04bbcdeb2b9e48b3ad57d8bf6'),
#                    <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='0a28c936-5214-4ba9-af28-339c1ad9f017', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='af0b22d8a6bdb895910a168632082e2a30014284b41c5110d2ccd4275da875fe')},
#  'start_char_idx': 0,
#  'text': 'Lorem ipsum dolor sit amet, consectetur adipiscing elit. Integer nec '
#          'odio. Praesent libero. Sed cursus ante dapibus diam. Sed nisi. Nulla '
#          'quis sem at nibh elementum imperdiet. Duis sagittis ipsum. Praesent '
#          'mauris.',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 304,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '0a28c936-5214-4ba9-af28-339c1ad9f017',
#  'metadata': {'block_index': 2,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': '116723b0-71ed-4e3f-aaea-6a78f653c053',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='f49aea42-6215-4727-b373-7cee31698a8c', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '116723b0-71ed-4e3f-aaea-6a78f653c053', 'page': None, 'block_index': 2, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='42832909301d3656a4c27177d3610e4778b653f04bbcdeb2b9e48b3ad57d8bf6'),
#                    <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='c21786e8-5384-40be-bd49-a80e2728a463', node_type=<ObjectType.TEXT: '1'>, metadata={'orig_doc_id': '116723b0-71ed-4e3f-aaea-6a78f653c053', 'page': None, 'block_index': 2, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='da3c5cee911aa0a6a2973f1759acf5ded433e4eb97d15c0cc470601892f7cc09')},
#  'start_char_idx': 176,
#  'text': 'Duis sagittis ipsum. Praesent mauris. Fusce nec tellus sed augue '
#          'semper porta. Mauris massa. Vestibulum lacinia arcu eget nulla.',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 213,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': 'cf668f41-4861-44cd-93e5-c465efcc3705',
#  'metadata': {'block_index': 3,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': '116723b0-71ed-4e3f-aaea-6a78f653c053',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='5eb1d1ae-9762-46f4-ad7d-9ae74b770d31', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '116723b0-71ed-4e3f-aaea-6a78f653c053', 'page': None, 'block_index': 3, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='7096a116a06e0d5a2724560adeb2c65fc87d2dff936c3e42eb484ef5a995d753'),
#                    <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='cc174734-502d-42a1-8e58-92716fb6be67', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='af0b22d8a6bdb895910a168632082e2a30014284b41c5110d2ccd4275da875fe')},
#  'start_char_idx': 0,
#  'text': 'Lorem ipsum dolor sit amet, consectetur adipiscing elit. Integer nec '
#          'odio. Praesent libero. Sed cursus ante dapibus diam. Sed nisi. Nulla '
#          'quis sem at nibh elementum imperdiet. Duis sagittis ipsum. Praesent '
#          'mauris.',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 304,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': 'cc174734-502d-42a1-8e58-92716fb6be67',
#  'metadata': {'block_index': 3,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': '116723b0-71ed-4e3f-aaea-6a78f653c053',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='5eb1d1ae-9762-46f4-ad7d-9ae74b770d31', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '116723b0-71ed-4e3f-aaea-6a78f653c053', 'page': None, 'block_index': 3, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='7096a116a06e0d5a2724560adeb2c65fc87d2dff936c3e42eb484ef5a995d753'),
#                    <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='cf668f41-4861-44cd-93e5-c465efcc3705', node_type=<ObjectType.TEXT: '1'>, metadata={'orig_doc_id': '116723b0-71ed-4e3f-aaea-6a78f653c053', 'page': None, 'block_index': 3, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='c409c3ba5b4218dc8dc642458df48798720d694c936a18651b646c4af738dc68')},
#  'start_char_idx': 176,
#  'text': 'Duis sagittis ipsum. Praesent mauris. Fusce nec tellus sed augue '
#          'semper porta. Mauris massa. Vestibulum lacinia arcu eget nulla.',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 213,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '7139f541-b511-4007-8e8c-c829613d1651',
#  'metadata': {'block_index': 4,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': '116723b0-71ed-4e3f-aaea-6a78f653c053',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='b1a6342a-c276-4005-b06e-5631ecae5fb4', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '116723b0-71ed-4e3f-aaea-6a78f653c053', 'page': None, 'block_index': 4, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='2570b3d2e38227aee4b4c310e7e8d28e760e4367b758019e2b62f1596d303cdc'),
#                    <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='c91f9f11-cf53-452e-877d-d0807b7c049c', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='af0b22d8a6bdb895910a168632082e2a30014284b41c5110d2ccd4275da875fe')},
#  'start_char_idx': 0,
#  'text': 'Lorem ipsum dolor sit amet, consectetur adipiscing elit. Integer nec '
#          'odio. Praesent libero. Sed cursus ante dapibus diam. Sed nisi. Nulla '
#          'quis sem at nibh elementum imperdiet. Duis sagittis ipsum. Praesent '
#          'mauris.',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 304,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': 'c91f9f11-cf53-452e-877d-d0807b7c049c',
#  'metadata': {'block_index': 4,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': '116723b0-71ed-4e3f-aaea-6a78f653c053',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='b1a6342a-c276-4005-b06e-5631ecae5fb4', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '116723b0-71ed-4e3f-aaea-6a78f653c053', 'page': None, 'block_index': 4, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='2570b3d2e38227aee4b4c310e7e8d28e760e4367b758019e2b62f1596d303cdc'),
#                    <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='7139f541-b511-4007-8e8c-c829613d1651', node_type=<ObjectType.TEXT: '1'>, metadata={'orig_doc_id': '116723b0-71ed-4e3f-aaea-6a78f653c053', 'page': None, 'block_index': 4, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='a1cdeff4006e872ed795fd74eb4796a2b9339669b4561c3ad0e87a950a23b1b8')},
#  'start_char_idx': 176,
#  'text': 'Duis sagittis ipsum. Praesent mauris. Fusce nec tellus sed augue '
#          'semper porta. Mauris massa. Vestibulum lacinia arcu eget nulla.',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 39,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': 'be2c6881-5b6d-433c-8b92-816e1e587cb5',
#  'metadata': {'block_index': 0,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': 'b49ad0dd-288b-4f03-a97e-7301851e593d',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='2ad4cde5-d094-4abb-87d2-3130f6ed3f60', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': 'b49ad0dd-288b-4f03-a97e-7301851e593d', 'page': None, 'block_index': 0, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='28c891c4409afc3ca7505c2892a2302c4776624aaac867d01895080905a57895')},
#  'start_char_idx': 0,
#  'text': '# Understanding Mixed Content Documents',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 260,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '70bbae17-d5ad-40e6-a9b4-baa0de53ba45',
#  'metadata': {'block_index': 1,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': 'b49ad0dd-288b-4f03-a97e-7301851e593d',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='d0d16cdd-7883-4f19-b322-3683556fa7d5', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': 'b49ad0dd-288b-4f03-a97e-7301851e593d', 'page': None, 'block_index': 1, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='1b528f76fcbd837a4fa7a392f8ae719b6e6b531c686d74a77bdc77efc17007c2')},
#  'start_char_idx': 0,
#  'text': 'When parsing documents for RAG, mixed content such as narrative '
#          'text, code, and tables requires careful detection and specialized '
#          'chunking strategies. The following pages include examples of code '
#          'blocks and tables to help develop and evaluate hybrid splitters.',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 31,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '850f6cf5-7927-4739-96b5-be4e474e0ba8',
#  'metadata': {'block_index': 2,
#               'detected_code': True,
#               'detected_table': False,
#               'orig_doc_id': 'b49ad0dd-288b-4f03-a97e-7301851e593d',
#               'page': None,
#               'splitter': 'code_fallback',
#               'splitter_used': 'code_fallback'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='c6d10a78-4e42-4eee-b7b2-30203ebd48c9', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': 'b49ad0dd-288b-4f03-a97e-7301851e593d', 'page': None, 'block_index': 2, 'detected_code': True, 'detected_table': False, 'splitter': 'code_fallback'}, hash='762a4843ae0719d506c684f18e9134042ed556a1ce4435a8745977ee7c5beabc')},
#  'start_char_idx': 0,
#  'text': '# Checklist for hybrid parsing:',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 291,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '009d70c3-369f-4699-8107-f4c85f14beb8',
#  'metadata': {'block_index': 3,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': 'b49ad0dd-288b-4f03-a97e-7301851e593d',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='4aded754-2006-4a96-8507-66cde7a0d919', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': 'b49ad0dd-288b-4f03-a97e-7301851e593d', 'page': None, 'block_index': 3, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='0e73c9bf330a21350b005ca769ac4c8ccfa1eb409223bcafa26ad37296aef37a')},
#  'start_char_idx': 0,
#  'text': '- Detect code blocks (monospace fonts, fenced blocks, indentation, '
#          'code keywords).\n'
#          '- Detect tables and preserve row/column structure when needed.\n'
#          '- Use sentence or token splitters for prose and code-aware splitters '
#          'for code.\n'
#          '- Preserve provenance (page number, block offsets, splitter used).',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 43,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': 'e148c1e1-179a-41ed-9ca7-1313bd33df12',
#  'metadata': {'block_index': 1,
#               'detected_code': True,
#               'detected_table': False,
#               'orig_doc_id': 'e545c2b6-0feb-473f-b0aa-5201d0a963b5',
#               'page': None,
#               'splitter': 'code_fallback',
#               'splitter_used': 'code_fallback'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='53e7a4d1-945d-4e5d-9314-96bd75f5e98b', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': 'e545c2b6-0feb-473f-b0aa-5201d0a963b5', 'page': None, 'block_index': 1, 'detected_code': True, 'detected_table': False, 'splitter': 'code_fallback'}, hash='595c033eaf220ec7638ada130465f589261cb88d204ce149c1f15eebe3b3d56d')},
#  'start_char_idx': 0,
#  'text': '# Python Code Example: Fibonacci (Function)',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 226,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': 'df76e4fa-0e64-4acf-affc-30947e980a0a',
#  'metadata': {'block_index': 2,
#               'detected_code': True,
#               'detected_table': False,
#               'orig_doc_id': 'e545c2b6-0feb-473f-b0aa-5201d0a963b5',
#               'page': None,
#               'splitter': 'code_fallback',
#               'splitter_used': 'code_fallback'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='5038151b-0dca-4d93-a523-ef0baac700ef', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': 'e545c2b6-0feb-473f-b0aa-5201d0a963b5', 'page': None, 'block_index': 2, 'detected_code': True, 'detected_table': False, 'splitter': 'code_fallback'}, hash='1523178737a164eccf0771532c659e2320137674510266a395e51be166935aa5')},
#  'start_char_idx': 0,
#  'text': 'def fibonacci(n):\n'
#          '"""Return a list of Fibonacci numbers up to n (inclusive)."""\n'
#          'if n &#x3C; 0:\n'
#          'raise ValueError("n must be non-negative")\n'
#          'seq = [0, 1]\n'
#          'while seq[-1] + seq[-2] &#x3C;= n:\n'
#          'seq.append(seq[-1] + seq[-2])\n'
#          'return seq',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 54,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': 'b74e5eb0-7c6f-454f-9017-068453f60eca',
#  'metadata': {'block_index': 3,
#               'detected_code': True,
#               'detected_table': False,
#               'orig_doc_id': 'e545c2b6-0feb-473f-b0aa-5201d0a963b5',
#               'page': None,
#               'splitter': 'code_fallback',
#               'splitter_used': 'code_fallback'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='dd867fbe-7d87-45a6-a851-9918149aa00a', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': 'e545c2b6-0feb-473f-b0aa-5201d0a963b5', 'page': None, 'block_index': 3, 'detected_code': True, 'detected_table': False, 'splitter': 'code_fallback'}, hash='c555c42c2824b3189790dffd48d956c64cf8ae70f5e7a1cf0d3a86be1ad3f09e')},
#  'start_char_idx': 0,
#  'text': '# Example:\n# >>> fibonacci(10)\n# [0, 1, 1, 2, 3, 5, 8]',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 171,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': 'd10539a2-3b51-44f1-98f9-a11a2194e4c1',
#  'metadata': {'block_index': 4,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': 'e545c2b6-0feb-473f-b0aa-5201d0a963b5',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='6f80295b-60ea-4d9d-a614-e231fc274b2e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': 'e545c2b6-0feb-473f-b0aa-5201d0a963b5', 'page': None, 'block_index': 4, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='7d850b46a1c2355ccd65843615e126c103be66a082ac91d4acd824d74022fc28')},
#  'start_char_idx': 0,
#  'text': 'The code block above demonstrates a simple algorithm with comments '
#          'and an example invocation. Note the indentation and inline comments '
#          '— useful signals for code detectors.',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 39,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': 'f6c4a7b3-0a41-4a0f-824b-2d04ef15b811',
#  'metadata': {'block_index': 0,
#               'detected_code': True,
#               'detected_table': False,
#               'orig_doc_id': '738b8cec-f9ba-486a-a78f-09fb73ad4781',
#               'page': None,
#               'splitter': 'code_fallback',
#               'splitter_used': 'code_fallback'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='14b5aba9-27dc-4b61-94f9-924c1adefe23', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '738b8cec-f9ba-486a-a78f-09fb73ad4781', 'page': None, 'block_index': 0, 'detected_code': True, 'detected_table': False, 'splitter': 'code_fallback'}, hash='02fd41772f0fcfa7fe5c295e649091509f26321891fde62add1801d93a292018')},
#  'start_char_idx': 0,
#  'text': '# Python Code Example: Class and Script',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 62,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': 'e96bb079-6862-4f47-90e9-c28e788f6317',
#  'metadata': {'block_index': 1,
#               'detected_code': True,
#               'detected_table': False,
#               'orig_doc_id': '738b8cec-f9ba-486a-a78f-09fb73ad4781',
#               'page': None,
#               'splitter': 'code_fallback',
#               'splitter_used': 'code_fallback'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='2f41c402-18ea-4009-953a-2bad5d29e1dd', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '738b8cec-f9ba-486a-a78f-09fb73ad4781', 'page': None, 'block_index': 1, 'detected_code': True, 'detected_table': False, 'splitter': 'code_fallback'}, hash='36a6d78cb6be037c9f3b0c3781685414e52c91852ba7ef824cd1cd2030975a4e')},
#  'start_char_idx': 0,
#  'text': 'class Counter:\ndef __init__(self, start=0):\nself.value = start',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 69,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '9fda22b3-4121-4688-af57-bb274b8334c4',
#  'metadata': {'block_index': 2,
#               'detected_code': True,
#               'detected_table': False,
#               'orig_doc_id': '738b8cec-f9ba-486a-a78f-09fb73ad4781',
#               'page': None,
#               'splitter': 'code_fallback',
#               'splitter_used': 'code_fallback'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='2b979437-28f1-4ad4-b147-840ce8720841', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '738b8cec-f9ba-486a-a78f-09fb73ad4781', 'page': None, 'block_index': 2, 'detected_code': True, 'detected_table': False, 'splitter': 'code_fallback'}, hash='23eeb05efedfc7c578fc87de50f355b4b1437496455259fb18ec5f237cba87b1')},
#  'start_char_idx': 0,
#  'text': 'def increment(self, amount=1):\n'
#          'self.value += amount\n'
#          'return self.value',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 80,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '934abb29-1247-44a8-9bd4-897c233bdda9',
#  'metadata': {'block_index': 3,
#               'detected_code': True,
#               'detected_table': False,
#               'orig_doc_id': '738b8cec-f9ba-486a-a78f-09fb73ad4781',
#               'page': None,
#               'splitter': 'code_fallback',
#               'splitter_used': 'code_fallback'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='fae8df65-879c-4046-b5d6-45f4acd5fd8d', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '738b8cec-f9ba-486a-a78f-09fb73ad4781', 'page': None, 'block_index': 3, 'detected_code': True, 'detected_table': False, 'splitter': 'code_fallback'}, hash='cf8d0349564536ddcb53aa7eb9370b28797978f35555abf7a8e76dd9d42b62da')},
#  'start_char_idx': 0,
#  'text': 'if __name__ == "__main__":\n'
#          'c = Counter()\n'
#          'for i in range(5):\n'
#          'print(c.increment())',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 182,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '35c9983c-a603-445d-8e7c-ccb26409f4b4',
#  'metadata': {'block_index': 4,
#               'detected_code': True,
#               'detected_table': False,
#               'orig_doc_id': '738b8cec-f9ba-486a-a78f-09fb73ad4781',
#               'page': None,
#               'splitter': 'code_fallback',
#               'splitter_used': 'code_fallback'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='e30fa3e7-9757-400c-a0e4-eae414b3d71d', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '738b8cec-f9ba-486a-a78f-09fb73ad4781', 'page': None, 'block_index': 4, 'detected_code': True, 'detected_table': False, 'splitter': 'code_fallback'}, hash='9bf8b0101c8ea6c3f45999e3ecf9da8e24b4ddf98972f64a2be1f94fcf5c1839')},
#  'start_char_idx': 0,
#  'text': 'This page contains a short class definition and a small runnable '
#          'script — splitters should avoid breaking the class body and should '
#          'preserve function/class boundaries where possible.',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 43,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '85acc55f-d6c0-48ae-9fe2-38c6b0d11389',
#  'metadata': {'block_index': 0,
#               'detected_code': True,
#               'detected_table': False,
#               'orig_doc_id': 'bf1957e7-6e49-4a06-9c46-7f0f96221cb2',
#               'page': None,
#               'splitter': 'code_fallback',
#               'splitter_used': 'code_fallback'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='3ec1ea35-6b00-4e24-840e-74820a962e9e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': 'bf1957e7-6e49-4a06-9c46-7f0f96221cb2', 'page': None, 'block_index': 0, 'detected_code': True, 'detected_table': False, 'splitter': 'code_fallback'}, hash='b08c02d5686ab33b02729430a6f38343bc26e9e1e61b20f7e026184398c7ce0e')},
#  'start_char_idx': 0,
#  'text': '# Table Example: Sample Dataset (Employees)',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 290,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '6413e522-87ab-463e-aafd-14ec9cc039ab',
#  'metadata': {'block_index': 1,
#               'chunk_index': 0,
#               'detected_table': True,
#               'orig_doc_id': 'bf1957e7-6e49-4a06-9c46-7f0f96221cb2',
#               'page': None,
#               'splitter': 'table',
#               'splitter_used': 'table'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='62a97ce1-1f50-4613-acb6-8a8c2268c882', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': 'bf1957e7-6e49-4a06-9c46-7f0f96221cb2', 'page': None, 'block_index': 1, 'detected_table': True, 'splitter': 'table', 'chunk_index': 0}, hash='0ec5ac50c23698b9bc5d175dad231cdc15f540af1493831e464a19924b97e700')},
#  'start_char_idx': 0,
#  'text': '| ID | Name | Department | Salary (USD) |\n'
#          '| --- | --- | --- | --- |\n'
#          '| ---- | ----------- | ------------ | ------------ |\n'
#          '| E001 | Asha Kumar | Data Science | 85000 |\n'
#          '| E002 | Liam Patel | Engineering | 92000 |\n'
#          '| E003 | Mei Zhang | Research | 98000 |\n'
#          '| E004 | Carlos Ruiz | Product | 79000 |',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 122,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '49cb3880-7782-41b1-a47b-f99ed273bd1f',
#  'metadata': {'block_index': 2,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': 'bf1957e7-6e49-4a06-9c46-7f0f96221cb2',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='56a73390-e2fb-4f3f-b925-4bd85f0ac4c5', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': 'bf1957e7-6e49-4a06-9c46-7f0f96221cb2', 'page': None, 'block_index': 2, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='fba895340b195021f1675603ce077b47227d739b6d0e7577da8a9f1512164a12')},
#  'start_char_idx': 0,
#  'text': 'Tables should be detected and preserved so that rows/columns can be '
#          'reconstructed during retrieval or rendered accurately.',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 37,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': 'faa7f7db-6913-4c01-b908-1aca8004cf21',
#  'metadata': {'block_index': 0,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': '67eb6276-d3f3-4f9e-96d0-0a847a3bf34e',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='b36c3d2b-ca80-4884-841f-00cdad54f27e', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '67eb6276-d3f3-4f9e-96d0-0a847a3bf34e', 'page': None, 'block_index': 0, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='d29c11562d2269e5059889094052e5dd533e0e9edc85f984b511c595b342bc3b')},
#  'start_char_idx': 0,
#  'text': '# Table Example: Experimental Results',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 327,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '2efa36af-e31d-4af7-967a-e90f31d21188',
#  'metadata': {'block_index': 1,
#               'chunk_index': 0,
#               'detected_table': True,
#               'orig_doc_id': '67eb6276-d3f3-4f9e-96d0-0a847a3bf34e',
#               'page': None,
#               'splitter': 'table',
#               'splitter_used': 'table'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='7831009d-144a-429e-a784-5252b5a27f13', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '67eb6276-d3f3-4f9e-96d0-0a847a3bf34e', 'page': None, 'block_index': 1, 'detected_table': True, 'splitter': 'table', 'chunk_index': 0}, hash='66b7ee598ba0a18bbe2e921ef69fe5afe89c1e5f83b2fb74da5dfda71ba0260f')},
#  'start_char_idx': 0,
#  'text': '| Experiment | Param A | Param B | Accuracy |\n'
#          '| --- | --- | --- | --- |\n'
#          '| ---------- | ------- | ------- | -------- |\n'
#          '| Exp-1 | 0.1 | 0.05 | 0.81 |\n'
#          '| Exp-2 | 0.2 | 0.10 | 0.82 |\n'
#          '| Exp-3 | 0.3 | 0.15 | 0.83 |\n'
#          '| Exp-4 | 0.4 | 0.20 | 0.84 |\n'
#          '| Exp-5 | 0.5 | 0.25 | 0.85 |\n'
#          '| Exp-6 | 0.6 | 0.30 | 0.86 |\n'
#          '| Exp-7 | 0.7 | 0.35 | 0.87 |',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 75,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '17704c89-e64c-4449-a53c-e726cdca674f',
#  'metadata': {'block_index': 2,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': '67eb6276-d3f3-4f9e-96d0-0a847a3bf34e',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='b4077cca-bb5a-443a-9e27-f9e6139d08e6', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '67eb6276-d3f3-4f9e-96d0-0a847a3bf34e', 'page': None, 'block_index': 2, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='ee164cf43411480c5180b3f8bf096178ffe84b127263980d5cb9166a867196ca')},
#  'start_char_idx': 0,
#  'text': 'This table lists a series of experimental runs and their measured '
#          'accuracy.',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 49,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': 'baed6de2-4a7e-4c23-b46e-31f558835810',
#  'metadata': {'block_index': 0,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': 'aa07f1e9-15fd-4c88-b55f-8af0cbf0435b',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='f07dd336-1fc8-4f70-b6be-bab8c0924ca4', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': 'aa07f1e9-15fd-4c88-b55f-8af0cbf0435b', 'page': None, 'block_index': 0, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='0fe70a98d8a18c073e6d9cc75d691495bf9b9cda86b159847b4cecada0f62023')},
#  'start_char_idx': 0,
#  'text': '# Mixed Example: Explanation + Code + Small Table',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 192,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': 'd06e5207-1710-486b-8e84-bbdc4ebfe82d',
#  'metadata': {'block_index': 1,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': 'aa07f1e9-15fd-4c88-b55f-8af0cbf0435b',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='6c578acd-c850-40d9-bd53-94c936df1156', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': 'aa07f1e9-15fd-4c88-b55f-8af0cbf0435b', 'page': None, 'block_index': 1, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='50a7f511d8d20cc8b37181d3eb04b0a787f08865c0fa6519e013094cc7d7022b')},
#  'start_char_idx': 0,
#  'text': 'Below is an explanation followed by a short code snippet and a tiny '
#          'result table. This simulates a common pattern in programming books '
#          'where theory, code, and results coexist on the same page.',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 50,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': 'd580bf52-485e-4134-a1a7-11cd6828e748',
#  'metadata': {'block_index': 2,
#               'detected_code': True,
#               'detected_table': False,
#               'orig_doc_id': 'aa07f1e9-15fd-4c88-b55f-8af0cbf0435b',
#               'page': None,
#               'splitter': 'code_fallback',
#               'splitter_used': 'code_fallback'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='6cb5c41a-0226-44c5-be15-af037cbecc37', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': 'aa07f1e9-15fd-4c88-b55f-8af0cbf0435b', 'page': None, 'block_index': 2, 'detected_code': True, 'detected_table': False, 'splitter': 'code_fallback'}, hash='8d8d4992333f6319a0f13174bea63e7a42db5f4ce47945e3c3c25cc9e79b6ad9')},
#  'start_char_idx': 0,
#  'text': 'def mean(values):\nreturn sum(values) / len(values)',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 46,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '46590e5e-868e-4f43-98f0-edbe89abdb3a',
#  'metadata': {'block_index': 3,
#               'detected_code': True,
#               'detected_table': False,
#               'orig_doc_id': 'aa07f1e9-15fd-4c88-b55f-8af0cbf0435b',
#               'page': None,
#               'splitter': 'code_fallback',
#               'splitter_used': 'code_fallback'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='e5111a13-1053-4456-876d-6a729ff1b990', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': 'aa07f1e9-15fd-4c88-b55f-8af0cbf0435b', 'page': None, 'block_index': 3, 'detected_code': True, 'detected_table': False, 'splitter': 'code_fallback'}, hash='49df0273db1d8c693ccf4cd4e1df44bb14a37d7497c6f35f36413f7df7307d02')},
#  'start_char_idx': 0,
#  'text': 'vals = [2, 4, 6, 8]\nprint("Mean:", mean(vals))',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 80,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '5381207f-e6bf-4a6b-b4cd-74ca1a0c2971',
#  'metadata': {'block_index': 4,
#               'chunk_index': 0,
#               'detected_table': True,
#               'orig_doc_id': 'aa07f1e9-15fd-4c88-b55f-8af0cbf0435b',
#               'page': None,
#               'splitter': 'table',
#               'splitter_used': 'table'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='2d6af6d8-f585-459d-a05f-af307c8af3fe', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': 'aa07f1e9-15fd-4c88-b55f-8af0cbf0435b', 'page': None, 'block_index': 4, 'detected_table': True, 'splitter': 'table', 'chunk_index': 0}, hash='7254b4cc592a1710d3ff662be186be5a6bb2ff704994ded0a0ebc14a43baa89e')},
#  'start_char_idx': 0,
#  'text': '| Metric | Value |\n'
#          '| --- | --- |\n'
#          '| ------ | ----- |\n'
#          '| Count | 4 |\n'
#          '| Mean | 5.0 |',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 39,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': 'd59541c6-1b31-40a8-af1a-ab445bca84d1',
#  'metadata': {'block_index': 1,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': '33613124-7e82-4408-b7aa-aaa3ea96b37a',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='8e5dd463-a655-4c8a-8e4d-6fc42af2f639', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '33613124-7e82-4408-b7aa-aaa3ea96b37a', 'page': None, 'block_index': 1, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='429cd96282d3cdfb05f3ecf05d297f9d75c9bbe0f181151ddd340edfccdd0e69')},
#  'start_char_idx': 0,
#  'text': '# Longer Code Listing: Utilities Module',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 53,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '85200751-398c-496f-a222-5cfd13a4fd4f',
#  'metadata': {'block_index': 2,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': '33613124-7e82-4408-b7aa-aaa3ea96b37a',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='1e52cefc-6e6f-4d28-8415-c27eb979c5f2', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '33613124-7e82-4408-b7aa-aaa3ea96b37a', 'page': None, 'block_index': 2, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='720d5249d0acc80d8316c24854915e12df524d1954387a399cbc67997b416195')},
#  'start_char_idx': 0,
#  'text': '"""Example module: simple linear algebra utilities"""',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 11,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '23bbeb2e-c266-4cc6-a3c2-a87015171917',
#  'metadata': {'block_index': 3,
#               'detected_code': True,
#               'detected_table': False,
#               'orig_doc_id': '33613124-7e82-4408-b7aa-aaa3ea96b37a',
#               'page': None,
#               'splitter': 'code_fallback',
#               'splitter_used': 'code_fallback'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='83672878-0314-4dff-b7b8-75da117535dd', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '33613124-7e82-4408-b7aa-aaa3ea96b37a', 'page': None, 'block_index': 3, 'detected_code': True, 'detected_table': False, 'splitter': 'code_fallback'}, hash='369ef36996fc3537a0207ef6a2cdf55f0f620c33827cb90cf02605d9109c78fe')},
#  'start_char_idx': 0,
#  'text': 'import math',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 50,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '6bdcc91a-5483-430e-bda6-4beb0e9f036a',
#  'metadata': {'block_index': 4,
#               'detected_code': True,
#               'detected_table': False,
#               'orig_doc_id': '33613124-7e82-4408-b7aa-aaa3ea96b37a',
#               'page': None,
#               'splitter': 'code_fallback',
#               'splitter_used': 'code_fallback'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='31a893fe-3680-48d1-b2b0-0153574198a2', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '33613124-7e82-4408-b7aa-aaa3ea96b37a', 'page': None, 'block_index': 4, 'detected_code': True, 'detected_table': False, 'splitter': 'code_fallback'}, hash='91b25dfd764a2da354221106892472efae5898ce2d0804d458ba017cffc6ee43')},
#  'start_char_idx': 0,
#  'text': 'def dot(a, b):\nreturn sum(x*y for x,y in zip(a,b))',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 39,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '33f40acc-2340-466a-a615-c24c5e677007',
#  'metadata': {'block_index': 5,
#               'detected_code': True,
#               'detected_table': False,
#               'orig_doc_id': '33613124-7e82-4408-b7aa-aaa3ea96b37a',
#               'page': None,
#               'splitter': 'code_fallback',
#               'splitter_used': 'code_fallback'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='307a3c27-6f5b-4812-882d-232ed4485f9c', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '33613124-7e82-4408-b7aa-aaa3ea96b37a', 'page': None, 'block_index': 5, 'detected_code': True, 'detected_table': False, 'splitter': 'code_fallback'}, hash='a4911e55e58d0186e1cadc9b16b0e58fc66344c905270afcd71594afae3ca991')},
#  'start_char_idx': 0,
#  'text': 'def norm(a):\nreturn math.sqrt(dot(a,a))',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 116,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '10d3fc92-50ab-415e-908c-eea524ce6f0e',
#  'metadata': {'block_index': 6,
#               'detected_code': True,
#               'detected_table': False,
#               'orig_doc_id': '33613124-7e82-4408-b7aa-aaa3ea96b37a',
#               'page': None,
#               'splitter': 'code_fallback',
#               'splitter_used': 'code_fallback'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='30b882e2-2161-4b9a-8d2b-20f9c1168a85', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '33613124-7e82-4408-b7aa-aaa3ea96b37a', 'page': None, 'block_index': 6, 'detected_code': True, 'detected_table': False, 'splitter': 'code_fallback'}, hash='6ffe0a5b7aaceba17dfa4d754586fed16df5a11da02a37e6704f91472607decf')},
#  'start_char_idx': 0,
#  'text': 'def cosine_similarity(a, b):\n'
#          'na = norm(a)\n'
#          'nb = norm(b)\n'
#          'if na == 0 or nb == 0:\n'
#          'return 0.0\n'
#          'return dot(a,b) / (na * nb)',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 104,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': 'e354ce25-5b09-4d84-a7d1-79a27f5d386b',
#  'metadata': {'block_index': 7,
#               'detected_code': True,
#               'detected_table': False,
#               'orig_doc_id': '33613124-7e82-4408-b7aa-aaa3ea96b37a',
#               'page': None,
#               'splitter': 'code_fallback',
#               'splitter_used': 'code_fallback'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='2fa825bf-f105-4a9f-8692-73cf5cf4ea0d', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '33613124-7e82-4408-b7aa-aaa3ea96b37a', 'page': None, 'block_index': 7, 'detected_code': True, 'detected_table': False, 'splitter': 'code_fallback'}, hash='80132de5879c10a5ab0b268245c35574d8e5f0e1612dac8ed8de64bd15f9acaa')},
#  'start_char_idx': 0,
#  'text': '# Usage:\n'
#          '# >>> cosine_similarity([1,0,0], [0,1,0])\n'
#          '# 0.0\n'
#          '# >>> cosine_similarity([1,1,0], [1,1,0])\n'
#          '# 1.0',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 25,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '249c02a2-4512-434e-b7d9-75c80d81f387',
#  'metadata': {'block_index': 0,
#               'detected_code': True,
#               'detected_table': False,
#               'orig_doc_id': '6b57655a-02fc-4c14-9b39-db91eb85b13a',
#               'page': None,
#               'splitter': 'code_fallback',
#               'splitter_used': 'code_fallback'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='dabd3301-ae48-4ae5-808e-7ed43d60f115', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '6b57655a-02fc-4c14-9b39-db91eb85b13a', 'page': None, 'block_index': 0, 'detected_code': True, 'detected_table': False, 'splitter': 'code_fallback'}, hash='d21f79bc0a14929231f606156ed68777001d22d30e0de4cf704887b126a990cc')},
#  'start_char_idx': 0,
#  'text': '# Conclusion &#x26; Index',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 208,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '5c293f6d-027b-44f8-8f5e-63ddf5dc83b4',
#  'metadata': {'block_index': 1,
#               'detected_code': False,
#               'detected_table': False,
#               'orig_doc_id': '6b57655a-02fc-4c14-9b39-db91eb85b13a',
#               'page': None,
#               'splitter': 'sentence',
#               'splitter_used': 'sentence'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='6df13fe7-c530-4f0a-9df8-8e9fea426bce', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '6b57655a-02fc-4c14-9b39-db91eb85b13a', 'page': None, 'block_index': 1, 'detected_code': False, 'detected_table': False, 'splitter': 'sentence'}, hash='8cd0a03102e5ed3eb9244673384418ded3d02b32a6428ad5cbc4ad0bf278ef84')},
#  'start_char_idx': 0,
#  'text': 'This sample document intentionally mixes normal prose, code '
#          'examples, and tabular data to support testing hybrid chunking and '
#          'splitter-selection strategies. Below is an index of notable blocks '
#          'by page number.',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
#
# {'embedding': None,
#  'end_char_idx': 228,
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'id_': '7db89490-4ba3-4a9e-ac51-85f10c45fbd7',
#  'metadata': {'block_index': 2,
#               'detected_code': True,
#               'detected_table': False,
#               'orig_doc_id': '6b57655a-02fc-4c14-9b39-db91eb85b13a',
#               'page': None,
#               'splitter': 'code_fallback',
#               'splitter_used': 'code_fallback'},
#  'metadata_separator': '\n',
#  'metadata_seperator': '\n',
#  'metadata_template': '{key}: {value}',
#  'mimetype': 'text/plain',
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='50587321-2973-4b2c-89b1-7ed2de47708b', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'orig_doc_id': '6b57655a-02fc-4c14-9b39-db91eb85b13a', 'page': None, 'block_index': 2, 'detected_code': True, 'detected_table': False, 'splitter': 'code_fallback'}, hash='8b4437e90ac8f7da51addab628a1b87d0d375f47b1d6131dd4aae95b38d9786f')},
#  'start_char_idx': 0,
#  'text': '- Page 4: Fibonacci function (code)\n'
#          '- Page 5: Counter class (code)\n'
#          '- Page 6: Employees table\n'
#          '- Page 7: Experimental results table\n'
#          '- Page 8: Mixed example (text + code + small table)\n'
#          '- Page 9: Utilities module (long code listing)',
#  'text_template': '{metadata_str}\n\n{content}'}
#
# =====================================================
